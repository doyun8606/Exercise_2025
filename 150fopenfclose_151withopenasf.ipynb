# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/150fopenfclose_151withopenasf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open('myfile.txt','w',encoding = 'cp949')
f.close()

f = open('image.jpg','rb')
f.close()

# %%
f = open('myfile.txt','r')
readData = f.readlines()
f.close()

with open('myfile.txt','r') as f:
    readData = f.readlines()
