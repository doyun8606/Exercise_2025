# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/158ospathgetsize_159osremove.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import getsize

file1 = 'sunrise.jpg'
file2 = 'c:/data/temp/DJI_0128.MP4'
file3 = '../../temp/DJI_0129.MP4'

print(f'{file1}: {getsize(file1):,} 바이트')
print(f'{file2}: {getsize(file2):,} 바이트')
print(f'{file3}: {getsize(file3):,} 바이트')

# %%
from os import remove

target = 'mydata.txt'
k = input(f'<{target}>을 삭제하시겟습니까? (y/n)')
if k.lower() == 'y':
  remove(target)
  print(f'<{target}>을 삭제했습니다.')
else:
  print(f'<{target}>을 삭제하지 않았습니다.')
# Out:
# <mydata.txt>을 삭제하시겟습니까? (y/n)y
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-901224189.py in <cell line: 0>()
#       4 k = input(f'<{target}>을 삭제하시겟습니까? (y/n)')
#       5 if k.lower() == 'y':
# ----> 6   remove(target)
#       7   print(f'<{target}>을 삭제했습니다.')
#       8 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mydata.txt'
