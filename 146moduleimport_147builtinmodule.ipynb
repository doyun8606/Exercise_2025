# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/146moduleimport_147builtinmodule.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
print(f'sqrt(2) = {math.sqrt(2):.3f}')

import math as m
print(f'sqrt(2) = {m.sqrt(2):.3f}')

from math import sqrt, log
print(f'sqrt(2) ={sqrt(2):.3f}')
print(f'log(2) = {log(2):.3f}')

#import mymodule
# Out:
# sqrt(2) = 1.414
# sqrt(2) = 1.414
# sqrt(2) =1.414
# log(2) = 0.693

# %%
#import amtplotlib
