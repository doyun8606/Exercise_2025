# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/166ospathisfile_167json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from os.path import isdir

fileList = []
dirList = []

files = listdir('/')          # 현재 작업 디렉토리의 파일 리스트

for file in files:
    if isdir(file):
        dirList.append(f'<DIR> {file}')
    else:
        fileList.append(file)

fileList.sort()
dirList.sort()

for d in dirList:
    print(d)

for f in fileList:
    print(f)
# Out:
# .dockerenv
# bin
# boot
# content
# datalab
# dev
# etc
# home
# kaggle
# lib
# lib32
# lib64
# libx32
# media
# mnt
# opt
# proc
# python-apt
# python-apt.tar.xz
# root
# run
# sbin
# srv
# sys
# tmp
# tools
# usr
# var

# %%
import json

with open('package.json') as f:
  data = json.load(f)
print(data)

profile = {'name':'조조','age':45,'nationality':'위나라',
           'skill':['집착','배신'],'alive':True}
with open('profile.json','w') as f:
  json.dump(profile,f,indent=4)

with open('profile.json','w') as f:
  data = json.load(f)
print(data)

with open('profile.json','w') as f:
  json.dump(profile,f,indent=4,ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3543366539.py in <cell line: 0>()
#       1 import json
#       2
# ----> 3 with open('package.json') as f:
#       4   data = json.load(f)
#       5 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'package.json'
