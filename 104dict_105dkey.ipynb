# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/104dict_105dkey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
population = {'서울':9407540,'부산':3320276,'인천':2964820}

populaion = dict(서울=9407540,부산=3320276,인천=2964820)
print(populaion)

population = dict([('서울',9407540),('부산',3320276),('인천',2964820)])
print(population)
# Out:
# {'서울': 9407540, '부산': 3320276, '인천': 2964820}
# {'서울': 9407540, '부산': 3320276, '인천': 2964820}

# %%
population = {'서울':9407540,'부산':3320276,'인천':2964820}
pnum = population['서울']
print(f'2022년 기준 서울의 인구는 {pnum:,d}명 입니다.')

orddict = {97:'a',98:'b',99:'c'}
print(f'ASCII 코드 97은 문자 {orddict[97]}에 대응됩니다.')

ret = orddict[95]
# Out:
# 2022년 기준 서울의 인구는 9,407,540명 입니다.
# ASCII 코드 97은 문자 a에 대응됩니다.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2975642249.py in <cell line: 0>()
#       6 print(f'ASCII 코드 97은 문자 {orddict[97]}에 대응됩니다.')
#       7
# ----> 8 ret = orddict[95]
#
# KeyError: 95
