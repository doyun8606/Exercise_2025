# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/128lambda_129annotation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lambda 매개변ㄴ수1, 매개변수2, ...:리턴 식

f =lambda x: x**2
print(f(2))
print(f(3))

f=lambda x:x +'.txt'
print(f('readme'))

f = lambda x:x[1]
print(f('readme'))
print(f(('장비',10)))
# Out:
# 4
# 9
# readme.txt
# e
# 10

# %%
from inspect import getgeneratorstate
def setLevel(character:str,level: int) -> dict[str,int]:
  return {character:level}

def setLevel(character: str, level: int) -> None:
  global greats
  greats[character] = level
  return

greats = {'유비':10,'관우':15,'장비':10}
setLevel('유비',13)
print(greats)
# Out:
# {'유비': 13, '관우': 15, '장비': 10}
