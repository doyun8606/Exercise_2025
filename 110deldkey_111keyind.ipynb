# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/110deldkey_111keyind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = {'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
del names['Mary']
print(names)

del names['Sams']
# Out:
# {'Cris': 2111, 'Aimy': 9778, 'Tom': 20245}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3207002977.py in <cell line: 0>()
#       3 print(names)
#       4
# ----> 5 del names['Sams']
#
# KeyError: 'Sams'

# %%
names = {'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
name = input('이름을 입력하세요.')
if name in names:
  print(f'이름이 <{name}>인 출생아 수는 <{names[name]:,d}>입니다')
else:
  print(f'딕셔너리 names에 <{name}>인 이름이 존재하지 않습니다.')
