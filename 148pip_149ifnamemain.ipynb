# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/148pip_149ifnamemain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
>pip install <패키지 이름>
>pip uninstall <패키지 이름>

>pip install matplotlib

import matplotlib

>pip list

# %%
def printName():
  print(f'module_b의___name__={__name__}')

from module_b import printName

printName()
print(f'실행 모듈인 이 모듈의 __name__={__name__}')

def printName():
  print(f'module_b의___name__={__name__}')

if __name__ == '__main__':
  print('이 모듈은 처음 실행되는 코드입니다.')
  printName()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3221942482.py in <cell line: 0>()
#       2   print(f'module_b의___name__={__name__}')
#       3
# ----> 4 from module_b import printName
#       5
#       6 printName()
#
# ModuleNotFoundError: No module named 'module_b'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
