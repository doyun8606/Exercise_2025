# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/130decorator_131class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def report():
  print('이 부분은 리포트의 본문입니다.')

def makeNumber():
  for i in range(3):
    print(i)

report()

makeNumber()

def report1():
  print('-'*50)
  print('이 부분은 리포트의 본문입니다.')
  print('-'*50)
  return

def makeNumber1():
  print('-'*50)
  for i in range(3):
    print(i)
  print('-'*50)
  return

def makeForm(func):
  def drawLine():
    print('-'*50)
    func()
    print('-'*50)
  return drawLine

report_new = makeForm(report)
report_new()

def drawLine():
  print('-'*50)
  report()
  print('-'*50)

makeNUmber_new = makeForm(makeNumber)
makeNUmber_new()

@makeForm
def report():
  print('이 부분은 리포트의 본문입니다.')
  return

#report()를 실행하면 아래의 코드와 같이 수행하세요
ret = makeForm(report)
ret()

report_new = makeForm(report)
report_new()

report()

def decoFunc(func):
  def wrapper(*args,**kwargs):
    func(*args,**kwargs)
  return wrapper
# Out:
# 이 부분은 리포트의 본문입니다.
# 0
# 1
# 2
# --------------------------------------------------
# 이 부분은 리포트의 본문입니다.
# --------------------------------------------------
# --------------------------------------------------
# 0
# 1
# 2
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# 이 부분은 리포트의 본문입니다.
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# 이 부분은 리포트의 본문입니다.
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# 이 부분은 리포트의 본문입니다.
# --------------------------------------------------

# %%
class wizzard:
  num_of_generated = 0
  def setName(self,name):
    self.name = name

player1 =wizzard()
player1.setName('FirePlayer')
print(player1.name)
# Out:
# FirePlayer
