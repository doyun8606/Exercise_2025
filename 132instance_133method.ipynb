# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/132instance_133method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Wizard:
    generated = 0              # 마법사 캐릭터 생성 수, 클래스 변수로 정의

    def __init__(self, name):  # 클래스 생성자
        Wizard.generated += 1  # 캐릭터가 생성되면 클래스 변수 1 증가
        self.name = name       # 캐릭터 이름 설정
        self.level = 1         # 최초 레벨 1로 설정
        self.hp = 100          # 최초 체력 100으로 설정
        self.initAbility()     # 능력치 초기화

    def initAbility(self):     # 능력치 초기화 메서드
        self.strength = 1      # 힘
        self.offense_power = 1 # 공격력
        self.intelligence = 10 # 지능
        self.mentality = 10    # 정신력
        self.agility = 1       # 민첩성

player1 = Wizard('FirePlayer')
print(f'마법사생성 수: {player1.generated}\n캐릭터이름: {player1.name}')

player2 = Wizard('GodGo')
print(f'마법사생성 수: {player2.generated}\n캐릭터이름: {player2.name}')

player1.level = 2
print(f'player1.level={player1.level},player2.level={player2.level}')

player1 = Wizard('StormBaby')
print(player1.generated)
# Out:
# 마법사생성 수: 1
# 캐릭터이름: FirePlayer
# 마법사생성 수: 2
# 캐릭터이름: GodGo
# player1.level=2,player2.level=1
# 3

# %%
class Wizard:
    generated = 0

    def setFireballLevel(self,power=1):
      self.fireballLevel = power
      print(f'화염구 강도를 {power}로 설정합니다.')

    @classmethod
    def addGenerated(cls,count):
      cls.generated += count
      print(f'생성된 총 캐릭터 수:{cls.generated}')

    @staticmethod
    def static1():
      print('Wizard 클래스에서 정의된 정적 메서드입니다.')

player1 = Wizard()
player1.setFireballLevel(8)
Wizard.addGenerated(2)
Wizard.static1()
# Out:
# 화염구 강도를 8로 설정합니다.
# 생성된 총 캐릭터 수:2
# Wizard 클래스에서 정의된 정적 메서드입니다.
