# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/120_dpopdpopitem_121dupdate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats = {'유비':89,'관우':95,'장비':91,'조운':94}
level = greats.pop('관우')
print(f'great:{greats}\nlevel:{level}')

#level = greats.pop('제갈량')

level = greats.pop('제갈량',99)
print(f'greats:{greats}\n제갈량의 레벨:{level}')

greats = {'유비':89,'관우':95,'장비':91,'조운':94}
while len(greats) > 0:
  general = greats.popitem()
  print(f'추출한 장군:{general}\ngreats 상태:{greats}')
  print('-'*50)

general = greats.popitem()
# Out:
# great:{'유비': 89, '장비': 91, '조운': 94}
# level:95
# greats:{'유비': 89, '장비': 91, '조운': 94}
# 제갈량의 레벨:99
# 추출한 장군:('조운', 94)
# greats 상태:{'유비': 89, '관우': 95, '장비': 91}
# --------------------------------------------------
# 추출한 장군:('장비', 91)
# greats 상태:{'유비': 89, '관우': 95}
# --------------------------------------------------
# 추출한 장군:('관우', 95)
# greats 상태:{'유비': 89}
# --------------------------------------------------
# 추출한 장군:('유비', 89)
# greats 상태:{}
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3359943199.py in <cell line: 0>()
#      14   print('-'*50)
#      15
# ---> 16 general = greats.popitem()
#
# KeyError: 'popitem(): dictionary is empty'

# %%
greats = {'유비':89,'관우':95,'장비':91,'조운':94}
others = {'제갈량':99,'황충':70}
greats.update(others)
print(greats)

greats.update(유비=90,관우=96)
print(greats)
# Out:
# {'유비': 89, '관우': 95, '장비': 91, '조운': 94, '제갈량': 99, '황충': 70}
# {'유비': 90, '관우': 96, '장비': 91, '조운': 94, '제갈량': 99, '황충': 70}
