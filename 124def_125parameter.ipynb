# %% [markdown]
# <a href="https://colab.research.google.com/github/doyun8606/Exercise_2025/blob/main/124def_125parameter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def func():  #func는 사용자가 정의하는 함수 이름
  코드
  return
#함수 호출 방법
func()

def func(매개변수1, 매개변수2, ...):
  코드
  return
func(인자1, 인자2, ...)

def func():
  코드
  return 리턴값
#함수 호출 방법
<리턴값을 받을 변수> = func()

def func(매개변수1, 매개변수2, ...):
  코드
  return 리턴값
#함수 호출 방법
<리턴값을 받을 변수> = func(인자1, 인자2, ...)

def displayFilepath():
  filepath = 'c:/myworks/pythonstrudy.py'
  print(f'파일경로:{filepath}')
  return
displayFilepath()

def printFilepath(folder, filename):
  print(f'파일경로:{folder+filename}')
  return

printFilepath('c:/myworks/','pythonstudy.py')

def getFilepath():
  filepath = 'c:/myworks/pythonstudy.py'
  return filepath

filepath = makeFilepath()
print(f'파일경로:{filepath}')

def makeFilepath(folder,filename):
  return folder + filename

filepath = getFilepath('c:/myworks/','pythonstudy.py')
print(f'파일경로:{filepath}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2083035350.py in <cell line: 0>()
#       3   return
#       4 #함수 호출 방법
# ----> 5 func()
#
# /tmp/ipython-input-2083035350.py in func()
#       1 def func():  #func는 사용자가 정의하는 함수 이름
# ----> 2   코드
#       3   return
#       4 #함수 호출 방법
#       5 func()
#
# NameError: name '코드' is not defined

# %%
def setLevel(character, level=1):
  print(f'{character}의 레벨:{level}')
  return

setLevel('유비')
setLevel('제갈량',10)

#def setLevel(level=1,character)

def setLevel(character,level):
  print(f'{character}의 레벨:{level}')
  return

setLevel(level=5,character='장비')

def setLevel(*args):
  print(args)
  return

setLevel('관우',7)
setLevel('조운','named',10)

def setLevel(**kwargs):
  print(kwargs)
  return

setLevel(character='조운',level=10)
setLevel(character='황충',category='named',level=5)

def setLevel(character, level, *args):
  print(f'장수:{character},레벨:{level}')
  if len(args) != 0:
    print(f'기타 특성:{args}')
  return

setLevel('조조',3)

setLevel('유비',3,'named','leader')

def setLevel(character,level,**kwargs):
  print(f'장수:{character},레벨:{level}')
  if len(kwargs) != 0:
    for k, v in kwargs.items():
      print(f'{k}:{v}')
  return

setLevel('조조',3)

setLevel('유비',3,category='named',position='leader')
# Out:
# 유비의 레벨:1
# 제갈량의 레벨:10
# 장비의 레벨:5
# ('관우', 7)
# ('조운', 'named', 10)
# {'character': '조운', 'level': 10}
# {'character': '황충', 'category': 'named', 'level': 5}
# 장수:조조,레벨:3
# 장수:유비,레벨:3
# 기타 특성:('named', 'leader')
# 장수:조조,레벨:3
# 장수:유비,레벨:3
# category:named
# position:leader
